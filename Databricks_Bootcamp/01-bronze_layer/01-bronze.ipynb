-- %% [markdown]
-- # **Volumes**

-- %%
%sql
create catalog if not exists dba;

-- %%
use catalog dba;
create schema if not exists  bronze;

-- %%
use catalog dba;
use schema bronze;
create volume if not exists autovol;

-- %%
%sql 
CREATE VOLUME IF NOT EXISTS dba.bronze.bronze_volume

-- %%
%sql
SELECT * FROM csv.`/Volumes/dba/bronze/bronze_volume/sales/fact_sales.csv`

-- %% [markdown]
-- # **DBUTILS**

-- %%
%python
dbutils.help()

-- %%
%python
dbutils.fs.ls("/Volumes/dba/bronze/bronze_volume/sales/")

-- %%
%python
dbutils.fs.mkdirs("/Volumes/dba/bronze/bronze_volume/customers")

-- %%
%python
dbutils.fs.cp("/Volumes/dba/bronze/bronze_volume/sales/","/Volumes/dba/bronze/bronze_volume/customers/",True)

-- %%
%python
dbutils.fs.rm("/Volumes/dba/bronze/bronze_volume/customers/fact_sales.csv")

-- %%
%python
dbutils.fs.put("/Volumes/dba/bronze/bronze_volume/customers/test.txt","True")

-- %%
%python
dbutils.fs.put("/Volumes/dba/bronze/bronze_volume/customers/test.py","print(Hello Ansh Lamba)",True)

-- %%
%python
all_items = dbutils.fs.ls("/Volumes/dba/bronze/bronze_volume/customers/")
all_items

-- %%
%python
file_names = [i.name for i in all_items]
file_names

-- %%
%python
for i in file_names:
    dbutils.fs.rm(f"/Volumes/dba/bronze/bronze_volume/customers/{i}")

-- %%
%python
dbutils.widgets.text("par1","")

-- %%
%python
par1_value = dbutils.widgets.get("par1")
par1_value

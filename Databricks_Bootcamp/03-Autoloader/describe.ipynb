-- %%
DESCRIBE table dba.bronze.copyintotbl

-- %%
DESCRIBE EXTENDED dba.bronze.copyintotbl

-- %%
DESCRIBE FORMATTED dba.bronze.copyintotbl

-- %%
DESCRIBE DETAIL dba.bronze.copyintotbl

-- %%
DESCRIBE HISTORY dba.bronze.copyintotbl

-- %%
DESCRIBE EXTENDED dba

-- %%
DESCRIBE schema dba

-- %%
select * from dba.bronze.copyintotbl version as of 1

-- %%
delete from dba.bronze.copyintotbl where order_id != 1

-- %%
select * from dba.bronze.copyintotbl

-- %%
describe history dba.bronze.copyintotbl

-- %%
select * from dba.bronze.copyintotbl @v3

-- %%
RESTORE dba.bronze.copyintotbl to version as of 2

-- %%
describe detail dba.bronze.copyintotbl

-- %%
select * from dba.bronze.copyintotbl

-- %%
select * from dba.bronze.copyintotbl

-- %%
create table dba.bronze.clone_copyintotbl
deep clone dba.bronze.copyintotbl

-- %%
describe history dba.bronze.clone_copyintotbl

-- %%
select * from dba.bronze.clone_copyintotbl

-- %%
create table dba.bronze.shallow_clone_copyintotbl
shallow clone dba.bronze.copyintotbl

-- %%
describe history dba.bronze.shallow_clone_copyintotbl

-- %%
select * from dba.bronze.shallow_clone_copyintotbl

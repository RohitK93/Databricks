-- %%
create table if not exists dba.bronze.lookup_table(
  parent_folder_name string,
  folder_name string
)

-- %%
insert into dba.bronze.lookup_table values
('raw', 'customers'),
('raw', 'sales'),
('raw', 'products'),
('raw', 'stores');

-- %%
select * from dba.bronze.lookup_table

# %%
# %sql
create volume if not exists dba.bronze.jobvolume

# %%
df = spark.read.format("csv") \
        .option("header", True) \
        .option("inferSchema", True) \
        .load("/Volumes/dba/bronze/bronze_volume/stores/")

# %%
df.write.format("delta") \
        .mode("overwrite") \
        .save("/Volumes/dba/bronze/jobvolume/raw/stores")
